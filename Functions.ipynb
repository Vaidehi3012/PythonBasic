# %% [markdown]
# #Functions

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#   - 1 Function : Defined using def keyword. It can be called independently Example : def greet(name): \n return "Hello, "+name \n print(greet("Vaidehi")
#   - 2 Method : A method is a function that is associated with an object. It is defined inside a class. Always called using .notation.
#   Example : class Person: \n def greet(self,name): \n return "Hello, "+name \n p=Person() \n print(p.greet("Vaid"))
# 2.  Explain the concept of function arguments and parameters in Python.
#   - Parameters are placeholders defined in the function definition. They act as variables that receive values when the function is called.
#   - Arguments are the actual values passed to the function when it is called.
#   - Example : ef greet(name): # name is parameter. \n return "Hello, "+name \n print(greet("Vaidehi") # vaidehi is argument.
# 3. What are the different ways to define and call a function in Python?
#   - 1 Regular Function. def greet(name): print("Hello, ",name)
#   #calling greet("Vaidehi")
#   - 2 Functions with default arguments. def greet(name="Guest"): print("Hello, ",name)
#   #calling greet(name="Vaidehi")
#   - 3 Functions with *args. def add(*numbers): total = sum(numbers) print("Sum is:",total)
#   #calling add(1, 2, 3, 4)
#   - 4 Function with **kwargs. def def print_info(**info): for key, value in info.items(): print(key, "=", value)
#   #calling print_info(name="Vaidehi", age=21)
#   - 5 Lambda Function. square = lambda x: x * x print(square(5))
#   #calling double = lambda x: x * 2 print(double(4))
# 4. What is the purpose of the `return` statement in a Python function?
#   - Ends the function execution.
#   - Sends data back to the caller.
#   - Allows you to store or use the result later.
#   - Example : def add(a, b): return a+b result= add(5, 3) print(result)
# 5. What are iterators in Python and how do they differ from iterables?
#   - An iterable is any Python object capable of returning its elements one at a time, allowing it to be iterated over in a loop (like a for loop). It must implement the __iter__() method, which returns an iterator.
#   - An iterable is an object that can return an iterator. Whereas iterator represents the stream of data.
# 6.  Explain the concept of generators in Python and how they are defined.
#   - Generator in Python is a special type of iterator that allows you to generate values on the fly, one at a time, using the yield keyword instead of return.
#   - A generator function is defined like a normal function, but uses the yield keyword to return a value each time it's called.
#   - Example : def countdown(n): while n > 0: yield n n =n-1 gen = countdown(3) print(next(gen)) print(next(gen)) print(next(gen))
# 7.  What are the advantages of using generators over regular functions?
#   - 1 Memory Efficiency -	Generators don’t store all values in memory. They generate values one at a time, which is useful for working with large data sets.
#   - 2 Lazy Evaluation	Generators produce values only when needed (on demand), which improves performance and reduces memory usage.
#   - 3 Simpler Syntax	Generators allow you to write cleaner and simpler code using yield instead of managing state manually.
# 8. What is a lambda function in Python and when is it typically used?
#   - A lambda function in Python is a small, anonymous function defined using the lambda keyword instead of def. It can take any number of arguments but has only one expression. The result of the expression is automatically returned.
#   - Example : square = lambda x: x * x print(square(5))
# 9. Explain the purpose and usage of the `map()` function in Python.
#   - The map() function in Python is used to apply a function to every item in an iterable (like a list, tuple, etc.) and return a new iterable (map object) containing the results.
#   - Example : numbers = [1, 2, 3, 4] squares = list(map(lambda x: x ** 2, numbers)) print(squares)
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#   - `The map()` function is used to apply a specific function to each item in an iterable (such as a list or tuple). It returns a new map object (which is an iterator) containing the results. The size of the output is the same as the input.
#   - `The filter()` function is used to select items from an iterable based on a condition defined in a function. Only items for which the function returns True are included in the result. The result is a filter object (iterator) containing the filtered elements.
#   - `The reduce()` function is used to apply a function cumulatively to the items of an iterable, from left to right. The function must take two arguments and return a single result. Unlike map() and filter(), reduce() returns a single value. It is available in the functools module.
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13]
#   - ![WhatsApp Image 2025-07-16 at 8.25.18 PM.jpeg](data:image/jpeg;base64,...)

# %%
#Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
def sum_even_numbers(numbers):
    sum = 0
    for num in numbers:
        if num % 2 == 0:
            sum += num
    return sum
sum_even_numbers([15,50,10,19])
# Out:
# 60

# %%
#Create a Python function that accepts a string and returns the reverse of that string.
def reverse_string(string):
    return string[::-1]
reverse_string("vaidehi")
# Out:
# 'ihediav'

# %%
#Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def square_numbers(numbers):
    squares = []
    for num in numbers:
        squares.append(num ** 2)
    return squares
square_numbers([1,2,3,4,5])
# Out:
# [1, 4, 9, 16, 25]

# %%
#Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(number):
    if number < 2:
        return False
    for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            return False
    return True
is_prime(21)
# Out:
# False

# %%
#Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
class Fibonacci:
    def __init__(self, n):
        self.n = n          # Number of terms
        self.a = 0
        self.b = 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n:
            raise StopIteration

        if self.count == 0:
            self.count += 1
            return self.a
        elif self.count == 1:
            self.count += 1
            return self.b
        else:
            next_num = self.a + self.b
            self.a = self.b
            self.b = next_num
            self.count += 1
            return next_num
fib = Fibonacci(5)
for num in fib:
    print(num)
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
#Write a generator function in Python that yields the powers of 2 up to a given exponent.
def powers_of_2(exponent):
    for i in range(exponent + 1):
        yield 2 ** i
for power in powers_of_2(5):
    print(power)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %%
#Implement a generator function that reads a file line by line and yields each line as a string.
def read_lines(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.strip()
    for line in read_lines("example.txt"):
      print(line)

# %%
#Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
data = [('apple', 3), ('banana', 1), ('cherry', 2)]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)
# Out:
# [('banana', 1), ('cherry', 2), ('apple', 3)]

# %%
#Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
celsius = [0, 20, 37, 100]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
print("Temperatures in Fahrenheit:", fahrenheit)
# Out:
# Temperatures in Fahrenheit: [32.0, 68.0, 98.6, 212.0]

# %%
#Create a Python program that uses `filter()` to remove all the vowels from a given string.
vowels = ['a', 'e', 'i', 'o', 'u']
string = "Hello, World!"
filtered_string = ''.join(filter(lambda x: x.lower() not in vowels, string))
print(filtered_string)
# Out:
# Hll, Wrld!

# %%
#Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the order is smaller than 100,00 €.
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]
result = list(map(
    lambda order: (order[0], order[2] * order[3] if order[2] * order[3] >= 100 else order[2] * order[3] + 10),
    orders
))
print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
